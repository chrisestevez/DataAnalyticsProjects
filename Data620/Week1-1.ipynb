# %% [markdown]
# # Christopher Estevez
# ## Week 1 Assignment

# %% [markdown]
# I first started by loading the required libraries matplot and networkx. I then move to create the nodes and edges and plot the graph. I had trouble generating the graph in a fixed position because every iteration created a distinct graph order. The ordering was solved by setting the seed to 14.

# %%
import matplotlib.pyplot as plt
import networkx as nx


# %matplotlib inline

# %%
seed(14)

pylab.rcParams["figure.figsize"] = (10, 10)

myGraph = nx.Graph()
myGraph.add_nodes_from(["Andre","Beverly","Carol","Diane","Ed","Ike","Garth","Jane","Fernando","Heather"])

myGraph.add_edges_from([("Andre","Beverly"),("Andre","Carol"),("Andre","Diane"),("Andre","Fernando"),
                        ("Beverly","Andre"),("Beverly","Ed"),("Beverly","Diane"),("Beverly","Garth"),
                       
                        ("Carol","Andre"),("Carol","Diane"),("Carol","Fernando"),
                        ("Diane","Andre"),("Diane","Beverly"),("Diane","Carol"),
                        ("Diane","Fernando"),("Diane","Garth"),("Diane","Ed"),
                        ("Ed","Beverly"),("Ed","Diane"),("Ed","Garth"),
                        ("Ike","Heather"),("Ike","Jane"),
                        ("Fernando","Carol"),("Fernando","Andre"),("Fernando","Diane"),
                        ("Fernando","Garth"),("Fernando","Heather"), 
                        
                       ("Heather","Garth"),("Heather","Fernando"),("Heather","Ike"),
                       ])
my_Pos=nx.spring_layout(myGraph)
nx.draw_networkx_nodes(myGraph,my_Pos,node_size=700, node_color="r")
nx.draw_networkx_edges(myGraph,my_Pos,alpha=0.4,width=5)
nx.draw_networkx_labels(myGraph,my_Pos,font_size=12,font_family="calibri")

plt.axis("off")
plt.show()

# %% [markdown]
# ## Sources
#
# ### https://networkx.github.io/documentation/networkx-1.9.1/tutorial/tutorial.html
# ### https://www.python-course.eu/networkx.php
